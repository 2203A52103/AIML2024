# %%
people = ['ann','dhoni','dhawan','sewag','kholi']
age = [18,35,65,34,54]
weight = [35,78,65,49,70]
height = [170,160,145,175,167]
import matplotlib.pyplot as plt
plt.scatter(weight,height)
plt.title("Relationship between weight and height of patients")
plt.ylabel("height in meters")
plt.xlabel("weight of patients in kgs")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16,fontstyle='italic')

plt.bar(x=people,height=weight,width=0.6,color='orange',edgecolor='k',alpha=0.6)

plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs),fontsize=15")
plt.show()

# %%
import numpy as np
plt.figure(figsize=(7,5))
plt.hist(weight,color='red',edgecolor='k', alpha=0.8,bins=5)
plt.title("histogram of patient weight",fontsize=20)
plt.xlabel("weight in kgs", fontsize=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# PART_3 ACCESS DATA FROM VARIOUS DATA SOURCES USING BULTIN FUNCTION OF NUMPY,PANDAS

# %%
import pandas as pd
file1=pd.read_csv("/content/AIML.csv")
print(file1)
# Out:
#    SN      NAME GENDER NATIONALITY ORGANIIZATION  WORK EXPERIENCE (IN YEARS)
# 0   1    MOHSIN      M       SAUDI         WIPRO                           9
# 1   2     VIKAS      M      INDIAN       INFOSYS                           8
# 2   3     PAVAN      M    CANADIAN     COGNIZANT                          10
# 3   4  ABHISHEK      M         USA        AMAZON                          10
# 4   5    SRAVAN      M    THAILAND     MICROSOFT                           9

# %%
import pandas as pd
file2=pd.read_table("/content/AIML.csv")
print(file2)
# Out:
#   SN,NAME,GENDER,NATIONALITY,ORGANIIZATION,WORK EXPERIENCE (IN YEARS)
# 0                           1,MOHSIN,M,SAUDI,WIPRO,9
# 1                         2,VIKAS,M,INDIAN,INFOSYS,8
# 2                    3,PAVAN,M,CANADIAN,COGNIZANT,10
# 3                         4,ABHISHEK,M,USA,AMAZON,10
# 4                    5,SRAVAN,M,THAILAND,MICROSOFT,9
